# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"C:\Users\dell\Downloads\HousingData.csv")

# %%
df = pd.read_csv(r"C:\Users\dell\Downloads\HousingData.csv")

# %%
print(df)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
print(df.columns)
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
x = df.drop(['MEDV'], axis=1)  
y = df[['MEDV']]

# %%
print(x.head(10))
print(y.head(10))
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87   NaN  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87   NaN  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90    NaN
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.20, random_state=4)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_train = x_train.dropna()
y_train = y_train.loc[x_train.index]  # Keep y in sync with x

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print("Coefficients of the model:")
print(reg.coef_)
# Out:
# Coefficients of the model:
# [[-1.20641621e-01  5.42493274e-02  5.48366967e-02  4.17035787e+00
#   -2.07184771e+01  3.84726945e+00 -2.01612755e-02 -1.70627645e+00
#    3.32222005e-01 -1.47533772e-02 -9.22143360e-01  8.86415394e-03
#   -4.35952412e-01]]

# %%
y_pred = reg.predict(x_test)
print("Predicted values:")
print(y_pred)
# Out:
# Predicted values:
# [[11.92763796]
#  [27.5607044 ]
#  [17.82959883]
#  [19.45942319]
#  [26.14896843]
#  [31.43436429]
#  [20.23922531]
#  [23.09562893]
#  [28.80546175]
#  [19.49259023]
#  [33.42667166]
#  [21.55268814]
#  [15.21806982]
#  [20.84525067]
#  [12.27065624]
#  [11.90204844]
#  [13.33176251]
#  [ 5.5510049 ]
#  [16.56994169]
#  [21.59179618]
#  [22.35055854]
#  [15.85512319]
#  [19.03591251]
#  [14.41479431]
#  [21.71020183]
#  [17.59232838]
#  [14.97530768]
#  [33.89069106]
#  [23.14399111]
#  [16.93827313]
#  [20.50794941]
#  [30.47301025]
#  [23.26142185]
#  [25.3569158 ]
#  [37.36708472]
#  [19.04821961]
#  [34.35480604]
#  [26.18861417]
#  [41.11680847]
#  [19.3155715 ]
#  [34.26509694]
#  [26.23895681]
#  [18.29668034]
#  [28.67883724]
#  [13.42574419]
#  [23.21586416]
#  [24.31791644]
#  [34.03916835]
#  [16.8723669 ]
#  [38.12846921]
#  [18.30909706]
#  [32.57745462]
#  [15.62173219]
#  [38.95747267]
#  [27.49649188]
#  [10.44155253]
#  [19.55504933]
# ...

# %%
# Drop rows with NaNs from both x and y
x_train = x_train.dropna()
y_train = y_train.loc[x_train.index]  # sync indices

x_test = x_test.dropna()
y_test = y_test.loc[x_test.index]     # sync indices

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)

y_pred = reg.predict(x_test)
print("Predicted values:")
print(y_pred)
# Out:
# Predicted values:
# [[11.92763796]
#  [27.5607044 ]
#  [17.82959883]
#  [19.45942319]
#  [26.14896843]
#  [31.43436429]
#  [20.23922531]
#  [23.09562893]
#  [28.80546175]
#  [19.49259023]
#  [33.42667166]
#  [21.55268814]
#  [15.21806982]
#  [20.84525067]
#  [12.27065624]
#  [11.90204844]
#  [13.33176251]
#  [ 5.5510049 ]
#  [16.56994169]
#  [21.59179618]
#  [22.35055854]
#  [15.85512319]
#  [19.03591251]
#  [14.41479431]
#  [21.71020183]
#  [17.59232838]
#  [14.97530768]
#  [33.89069106]
#  [23.14399111]
#  [16.93827313]
#  [20.50794941]
#  [30.47301025]
#  [23.26142185]
#  [25.3569158 ]
#  [37.36708472]
#  [19.04821961]
#  [34.35480604]
#  [26.18861417]
#  [41.11680847]
#  [19.3155715 ]
#  [34.26509694]
#  [26.23895681]
#  [18.29668034]
#  [28.67883724]
#  [13.42574419]
#  [23.21586416]
#  [24.31791644]
#  [34.03916835]
#  [16.8723669 ]
#  [38.12846921]
#  [18.30909706]
#  [32.57745462]
#  [15.62173219]
#  [38.95747267]
#  [27.49649188]
#  [10.44155253]
#  [19.55504933]
# ...
